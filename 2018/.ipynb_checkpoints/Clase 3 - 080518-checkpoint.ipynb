// %% [markdown]
// # Variables
// (Enteros) int (+,-,/,*,%)
//
// (Decimales) float (+,-,/,*,%)
//
// (Textos) String
//
// (Lógicos) boolean

// %% [markdown]
// ## Variables Enteras
// (Enteros) int (+,-,/,*,%)

// %%
int posX = 0;
void setup(){
    size(400, 400);
}
void draw(){
    background(255);
    posX = posX + 1;
    ellipse(posX, 200, 50, 50);
}
// Out:
// <div id="canvas_div_1">
//   <b>Sketch #1:</b><br/>
//   <canvas id="canvas_1"></canvas><br/>
// </div>
// <div id="controls_div_1">
//   <button id="run_button_1" onclick="startSketch('1');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_1" onclick="pauseSketch('1');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_1" onclick="setupSketch('1');">
//     setup()
//   </button>
//   <button id="draw_button_1" onclick="drawSketch('1');">
//     draw()
//   </button>
// </div>
// <b>Sketch #1 state:</b> <span id="state_1">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ## Variables Textos
// (Textos) String (+)
//
// La coordenada define la esquina inferior izquierda.

// %%
int posX = 0;
String miTexto = "Hola Processing! Cantidad: ";
void setup(){
    size(400, 400);
}
void draw(){
    background(0);
    text(miTexto,0,200);
    posX = posX + 1;
    miTexto = miTexto + posX;
}
// Out:
// <div id="canvas_div_2">
//   <b>Sketch #2:</b><br/>
//   <canvas id="canvas_2"></canvas><br/>
// </div>
// <div id="controls_div_2">
//   <button id="run_button_2" onclick="startSketch('2');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_2" onclick="pauseSketch('2');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_2" onclick="setupSketch('2');">
//     setup()
//   </button>
//   <button id="draw_button_2" onclick="drawSketch('2');">
//     draw()
//   </button>
// </div>
// <b>Sketch #2 state:</b> <span id="state_2">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ### Imprimimos en la pantalla el incremento de una variable entera

// %%
int posX = 0;
String miNuevoTexto = "";
String miTexto = "Cantidad: ";
void setup(){
    size(400, 400);
    textSize(40);
}
void draw(){
    background(0);
    posX = posX + 1;
    miNuevoTexto = miTexto + posX;
    text(miNuevoTexto,0,200);
}
// Out:
// <div id="canvas_div_3">
//   <b>Sketch #3:</b><br/>
//   <canvas id="canvas_3"></canvas><br/>
// </div>
// <div id="controls_div_3">
//   <button id="run_button_3" onclick="startSketch('3');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_3" onclick="pauseSketch('3');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_3" onclick="setupSketch('3');">
//     setup()
//   </button>
//   <button id="draw_button_3" onclick="drawSketch('3');">
//     draw()
//   </button>
// </div>
// <b>Sketch #3 state:</b> <span id="state_3">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ### Mostramos un texto descendiendo con el incremento de una variable entera

// %%
int posX = 0;
String miNuevoTexto = "";
String miTexto = "Cantidad: ";
void setup(){
    size(400, 400);
    textSize(40);
}
void draw(){
    background(0);
    posX = posX + 1;
    miNuevoTexto = miTexto + posX;
    text(miNuevoTexto,posX,posX);
}
// Out:
// <div id="canvas_div_4">
//   <b>Sketch #4:</b><br/>
//   <canvas id="canvas_4"></canvas><br/>
// </div>
// <div id="controls_div_4">
//   <button id="run_button_4" onclick="startSketch('4');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_4" onclick="pauseSketch('4');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_4" onclick="setupSketch('4');">
//     setup()
//   </button>
//   <button id="draw_button_4" onclick="drawSketch('4');">
//     draw()
//   </button>
// </div>
// <b>Sketch #4 state:</b> <span id="state_4">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// # División (/) y Módulo (%)
// Devuelve el resto de una división. Por ejemplo:
//
// 10/3 = 3,3333
//
// 10%3 = 1
//
// 40%10 = 0
//
// 5%2 = 1

// %%
int inc, division, modulo;
String miNuevoTexto;
void setup(){
    size(400, 400);
    textSize(30);
    inc = 0;
    modulo = 0;
}
void draw(){
    background(0);
    inc = inc + 1;
    division = floor(inc / 40);
    modulo = inc % 40;
    miNuevoTexto = "Division: " + inc + " / 40 = " + division;
    text(miNuevoTexto,10,100);
    miNuevoTexto = "Módulo: " + inc + " % 40 = " + modulo;
    text(miNuevoTexto,10,200);
}

// %% [markdown]
// ## Random
// Devuelve un número aleatorio en a y b
// random(10) -> Un valor entre 0 y 10 con decimales (float)
// random(5, 9) -> Un valor entre 5 y 9 con decimales (float)
//
// ## round
// Redondea el valor entero
// 7.3 -> 7
// 7.8 -> 8
//
// ## floor
// Me devuelve el entero
// 7.3 -> 7
// 7.8 -> 7
//
// ## ceil
// Me devuelve el siguiente valor entero
// 7.3 -> 8
// 7.8 -> 8

// %%
float valorFloat, valorInt;
String miNuevoTexto;
void setup(){
    size(400, 400);
    textSize(30);
    valorFloat = random(0, 10);
    valorInt = round(valorFloat);
    valorInt = floor(valorFloat);
    valorInt = ceil(valorFloat);
}
void draw(){
    background(0);
    miNuevoTexto = "Random: " + valorFloat;
    text(miNuevoTexto,0,100);
    miNuevoTexto = "Random: " + valorInt;
    text(miNuevoTexto,0,300);
}
// Out:
// <div id="canvas_div_5">
//   <b>Sketch #5:</b><br/>
//   <canvas id="canvas_5"></canvas><br/>
// </div>
// <div id="controls_div_5">
//   <button id="run_button_5" onclick="startSketch('5');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_5" onclick="pauseSketch('5');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_5" onclick="setupSketch('5');">
//     setup()
//   </button>
//   <button id="draw_button_5" onclick="drawSketch('5');">
//     draw()
//   </button>
// </div>
// <b>Sketch #5 state:</b> <span id="state_5">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ## Recuadros aleatorios

// %%
int cant = 10;
int tam;
int posX, posY;
void setup(){
    size(500, 500);
    textSize(30);
    tam = width/cant;
}
void draw(){
    posX = (round(random(0, width)) % cant) * tam;
    posY = (round(random(0, height)) % cant) * tam;
    fill(random(0,255), random(0,255), random(0,255));
    rect(posX,posY,tam, tam);
}
// Out:
// <div id="canvas_div_6">
//   <b>Sketch #6:</b><br/>
//   <canvas id="canvas_6"></canvas><br/>
// </div>
// <div id="controls_div_6">
//   <button id="run_button_6" onclick="startSketch('6');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_6" onclick="pauseSketch('6');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_6" onclick="setupSketch('6');">
//     setup()
//   </button>
//   <button id="draw_button_6" onclick="drawSketch('6');">
//     draw()
//   </button>
// </div>
// <b>Sketch #6 state:</b> <span id="state_6">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...
