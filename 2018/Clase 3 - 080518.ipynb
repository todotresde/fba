// %% [markdown]
// ## Variables
// (Enteros) int (+,-,/,*,%)
// (Decimales) float (+,-,/,*,%)
// (Textos) String
// (Lógicos) boolean

// %% [markdown]
// ## Variables Enteras
// (Enteros) int (+,-,/,*,%)

// %%
int posX = 0;
void setup(){
    size(400, 400);
}
void draw(){
    background(255);
    posX = posX + 1;
    ellipse(posX, 200, 50, 50);
}
// Out:
// <div id="canvas_div_2">
//   <b>Sketch #2:</b><br/>
//   <canvas id="canvas_2"></canvas><br/>
// </div>
// <div id="controls_div_2">
//   <button id="run_button_2" onclick="startSketch('2');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_2" onclick="pauseSketch('2');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_2" onclick="setupSketch('2');">
//     setup()
//   </button>
//   <button id="draw_button_2" onclick="drawSketch('2');">
//     draw()
//   </button>
// </div>
// <b>Sketch #2 state:</b> <span id="state_2">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ## Variables Textos
// (Textos) String (+)
// La coordenada define la esquina inferior izquierda.

// %%
int posX = 0;
String miTexto = "Hola Processing! Cantidad: ";
void setup(){
    size(400, 400);
}
void draw(){
    background(0);
    text(miTexto,0,200);
    posX = posX + 1;
    miTexto = miTexto + posX;
}
// Out:
// <div id="canvas_div_7">
//   <b>Sketch #7:</b><br/>
//   <canvas id="canvas_7"></canvas><br/>
// </div>
// <div id="controls_div_7">
//   <button id="run_button_7" onclick="startSketch('7');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_7" onclick="pauseSketch('7');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_7" onclick="setupSketch('7');">
//     setup()
//   </button>
//   <button id="draw_button_7" onclick="drawSketch('7');">
//     draw()
//   </button>
// </div>
// <b>Sketch #7 state:</b> <span id="state_7">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %%
int posX = 0;
String miNuevoTexto = "";
String miTexto = "Cantidad: ";
void setup(){
    size(400, 400);
    textSize(40);
}
void draw(){
    background(0);
    posX = posX + 1;
    miNuevoTexto = miTexto + posX;
    text(miNuevoTexto,0,200);
}
// Out:
// <div id="canvas_div_10">
//   <b>Sketch #10:</b><br/>
//   <canvas id="canvas_10"></canvas><br/>
// </div>
// <div id="controls_div_10">
//   <button id="run_button_10" onclick="startSketch('10');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_10" onclick="pauseSketch('10');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_10" onclick="setupSketch('10');">
//     setup()
//   </button>
//   <button id="draw_button_10" onclick="drawSketch('10');">
//     draw()
//   </button>
// </div>
// <b>Sketch #10 state:</b> <span id="state_10">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %%
int posX = 0;
String miNuevoTexto = "";
String miTexto = "Cantidad: ";
void setup(){
    size(400, 400);
    textSize(40);
}
void draw(){
    background(0);
    posX = posX + 1;
    miNuevoTexto = miTexto + posX;
    text(miNuevoTexto,posX,posX);
}
// Out:
// <div id="canvas_div_12">
//   <b>Sketch #12:</b><br/>
//   <canvas id="canvas_12"></canvas><br/>
// </div>
// <div id="controls_div_12">
//   <button id="run_button_12" onclick="startSketch('12');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_12" onclick="pauseSketch('12');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_12" onclick="setupSketch('12');">
//     setup()
//   </button>
//   <button id="draw_button_12" onclick="drawSketch('12');">
//     draw()
//   </button>
// </div>
// <b>Sketch #12 state:</b> <span id="state_12">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// # Módulo (%)
// ## !!!!DE TAREA!!!!!
// Devuelve el resto de una división. Por ejemplo:
// 10/3 = 3,3333
// 10%3 = 1
// 40%10 = 0
// 5%2 = 1

// %%
int inc = 0;
int modulo;
String miNuevoTexto;
void setup(){
    size(400, 400);
    textSize(30);
}
void draw(){
    background(0);
    inc = inc + 1;
    modulo = 400 % inc;
    miNuevoTexto = "Modulo: 40 % : " + inc + " = " + modulo;
    text(miNuevoTexto,0,200);
}
// Out:
// <div id="canvas_div_16">
//   <b>Sketch #16:</b><br/>
//   <canvas id="canvas_16"></canvas><br/>
// </div>
// <div id="controls_div_16">
//   <button id="run_button_16" onclick="startSketch('16');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_16" onclick="pauseSketch('16');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_16" onclick="setupSketch('16');">
//     setup()
//   </button>
//   <button id="draw_button_16" onclick="drawSketch('16');">
//     draw()
//   </button>
// </div>
// <b>Sketch #16 state:</b> <span id="state_16">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// ## Random
// Devuelve un número aleatorio en a y b
// random(10) -> Un valor entre 0 y 10 con decimales (float)
// random(5, 9) -> Un valor entre 5 y 9 con decimales (float)
//
// ## round
// Redondea el valor entero
// 7.3 -> 7
// 7.8 -> 8
//
// ## floor
// Me devuelve el entero
// 7.3 -> 7
// 7.8 -> 7
//
// ## ceil
// Me devuelve el siguiente valor entero
// 7.3 -> 8
// 7.8 -> 8

// %%
float valorFloat, valorInt;
String miNuevoTexto;
void setup(){
    size(400, 400);
    textSize(30);
    valorFloat = random(0, 10);
    valorInt = round(valorFloat);
    valorInt = floor(valorFloat);
    valorInt = ceil(valorFloat);
}
void draw(){
    background(0);
    miNuevoTexto = "Random: " + valorFloat;
    text(miNuevoTexto,0,100);
    miNuevoTexto = "Random: " + valorInt;
    text(miNuevoTexto,0,300);
}
// Out:
// <div id="canvas_div_21">
//   <b>Sketch #21:</b><br/>
//   <canvas id="canvas_21"></canvas><br/>
// </div>
// <div id="controls_div_21">
//   <button id="run_button_21" onclick="startSketch('21');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_21" onclick="pauseSketch('21');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_21" onclick="setupSketch('21');">
//     setup()
//   </button>
//   <button id="draw_button_21" onclick="drawSketch('21');">
//     draw()
//   </button>
// </div>
// <b>Sketch #21 state:</b> <span id="state_21">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// ## Recuadros aleatorios

// %%
int cant = 10;
int tam;
int posX, posY;
void setup(){
    size(500, 500);
    textSize(30);
    tam = width/cant;
}
void draw(){
    posX = (round(random(0, width)) % cant) * tam;
    posY = (round(random(0, height)) % cant) * tam;
    fill(random(0,255), random(0,255), random(0,255));
    rect(posX,posY,tam, tam);
}
// Out:
// <div id="canvas_div_41">
//   <b>Sketch #41:</b><br/>
//   <canvas id="canvas_41"></canvas><br/>
// </div>
// <div id="controls_div_41">
//   <button id="run_button_41" onclick="startSketch('41');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_41" onclick="pauseSketch('41');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_41" onclick="setupSketch('41');">
//     setup()
//   </button>
//   <button id="draw_button_41" onclick="drawSketch('41');">
//     draw()
//   </button>
// </div>
// <b>Sketch #41 state:</b> <span id="state_41">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...
